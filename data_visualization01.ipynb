# %% [markdown]
# <a href="https://colab.research.google.com/github/gopal2812/mlblr/blob/master/data_visualization01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 4 - Practical Data Visualization
# ## Segment 1 - Creating standard data graphics
#
#
# Creating standard data graphics
# - [Instructor] Now let's talk about how to create standard chart graphics. Standard chart graphics are excellent tools for conveying simple data insights in a way that anyone can understand. For example, imagine you're an eCommerce Business Analyst for a company that makes some major changes to its website layout. You're working on site usability and you need to convey your findings to your manager. So you decide that you're going to use a line chart, a bar chart, and a pie chart. You use the line chart to show how the total number of items purchased per day has increased since the change. You use the bar chart to show that the number of purchases increased for customers in the 18 to 25 year old category, but decreased for customers in the higher than 44 year old category. Lastly, you use a pie chart to show what categories of products generate the greatest proportion of sales, and how the site changes affected that proportion before and after. To summarize, you use a line chart to show changes overtime, you use a bar chart to show changes in categorical data, and you use a pie chart to show categorical data as proportions of a whole. Now, we have two methods for plot building, a functional method and an object-oriented method. In the demonstration we're about to do, I'm going to show you how to build plots using the functional method. With the functional method, you build plots by calling the plotting function on a variable or a set of variables. With object-oriented plotting, you build a plot by first generating a blank figure object and then populating that object with plot and plot element. We'll be doing that in later demonstrations. In the coding demonstration to come, I'm going to show you the most popular data visualizations in Python, those are Matplotlib and Seaborn. In this demonstration, I'm going to show you how to use Matplotlib, so let's get started. So here we have our Jupyter Notebook, and I am giving you the mtcars dataset here with the column names and everything prepared for you, just so we don't have to type that out again, but first things first, let's go ahead and import our libraries. We're going to import numpy as np, and then we are also going to generate random numbers in this demonstration. So from within numpy, we need to import randn. We'll also be using pandas. So we're going to import pandas as pd, and then from pandas, we'll import Series and DataFrame, and in this demonstration, I'm going to show you how to use Matplotlib for the first time. So let's just import matplotlib.pyplot. We'll need that pyplot module and we'll import it as plt. We'll also import rcParams from matplotlib. So we'll say, from matplotlib import rcParams. Great, and I'll just run this so we have our libraries. Now the first thing we're going to work on here, is we are just going to create some line charts. So for the first line chart, let's just generate two variables, an x and a y. X will be equal to a range of values between one and nine. So we're going to call the range function, and we're going to pass in 1 as the start digit, and then 10 as the end digit, and then for our y variable, we're going to set that equal to a list. The numbers in this list are going to be 1, 2, 3, 4, 0, 4, 3, 2, and 1. To generate the line plot, what we need to do is call the plot function. So we'll do that by saying, plt.plot, and then we'll pass in x and y, and run it, and here is our first line chart. That's pretty nice huh? Now let's work on creating a line chart from a pandas object. We've already got your data loaded and ready to go inside of the Jupyter environment, but we need to go ahead and isolate a variable. So let's isolate the mpg variable, and we'll just say mpg is equal to cars, and then select our mpg label index. Okay, so I'm going to run this, need to add an s here, and next let's plot it out. It's easy as that, so we will plot it out by calling the plot method, so that's mpg.plot here, and we'll run that, and now we have a line chart that shows the values in the mpg variable. The next thing that we're going to do, is we're just going to generate a line chart that's actually plotting out three variables. So to do that let's create a DataFrame called df, and we'll say that's equal to cars, and then we'll just go ahead and we'll select the variables we want to plot. So let's plot out cyl, wt, and mpg, and then to plot it out, you just call the plot method, so it's df.plot, and it's as easy as that. Pretty cool, huh? All right, let's now start looking at how to create bar charts. To create a bar chart, you just call the bar function, so that would be plt.bar, and then you pass in your variables, so we'll just pass in x and y, and run this, and it's as easy as that. We have our first bar chart. If you wanted to create a bar chart from a pandas object, you would just call the plot function. So let's plot out our mpg variable as a bar chart. To do that, we will say mpg.plot, and then what we need to do is pass in a parameter that says kind="bar", okay, and run that, and now we have our mpg variable plotted out as a bar chart. If you wanted to plot this horizontally instead of vertically, all you would do is use that same command, but then the kind is going to be barh, so I'll just add an h here and run that. Okay, easy peasy. The last thing I want to show you in this demonstration, is how to create pie charts. So for this example, let's create a new variable x, and it'll be a list that's comprised of the numbers 1, 2, 3, 4, and 0.5, okay, and then if you want to generate a pie chart from this, you would just call the pie function, and then say, plt.show. So, let me show you, that's plt.pie, and then we pass in our x variable, and then to actually show the pie chart, what we need to do is say, plt.show, and run that, and here we have our first pie chart. The last thing I want to show you here, is how to save this pie chart as an image file. So to do that, you would first generate the pie chart again using the pie function, so we'll say plt.pie, and then we'll pass in our x variable, and then we want to use the savefig function. So we will say, plt.savefig, and we'll pass in a filename, and to do that, we'll just create a string and we will call it piechart.png, so piechart, pie_chart.png. So we'll save that extension name there, and then we will say, plt.show, and we run this, and so as you can see, our same pie chart has plotted out again, but is actually been saved as an image, a png image, so let's look at that image. To identify where that image is stored on your machine, you would just identify the present working directory by saying, %pwd, running that, and okay, cool, so it's in 04_01. Let's go ahead and open that folder, and just take a quick look at that. In here is our png file. It has now been saved as an image in our working directory.

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# ### Creating a line chart from a list object

# %% [markdown]
# #### Plotting a line chart in matplotlib

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]

plt.plot(x,y)

# %% [markdown]
# #### Plotting a line chart from a Pandas object

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ls /content/gdrive/My\ Drive/Exercise\ Files/Data/
#root_path = 'gdrive/My Drive/your_project_folder/'  #change dir to your project folder
#data = pd.read_csv('gdrive/My Drive/Ex_Files_DSF_DataMining/Exercise Files/Ch2/02_04/data/b5.csv')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# 'analytics.usa.gov website.PNG'   iris.data.csv   parsed_data.txt
#  iris.csv			  mtcars.csv	  Superstore-Sales.csv

# %%
#address = 'gdrive/My Drive/Exercise\ Files/Data/mtcars.csv'
cars = pd.read_csv('gdrive/My Drive/Exercise Files/Data/mtcars.csv')
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

mpg = cars['mpg']

# %%
mpg.plot()

# %%
df = cars[['cyl','wt','mpg']]
df.plot()

# %% [markdown]
# ### Creating bar charts
# #### Creating a bar chart from a list

# %%
plt.bar(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-a6615192c27a> in <module>()
# ----> 1 plt.bar(x, y)
#
# NameError: name 'x' is not defined

# %% [markdown]
# #### Creating bar charts from Pandas objects

# %%
mpg.plot(kind="bar")

# %%
mpg.plot(kind="barh")

# %% [markdown]
# ### Creating a pie chart

# %%
x = [1,2,3,4,0.5]
plt.pie(x)
plt.show()

# %% [markdown]
# ### Saving a plot

# %%
plt.pie(x)
plt.savefig('pie_chart.png')
plt.show()

# %%
# %pwd
# Out:
# 'C:\\Users\\Lillian\\Desktop\\ExerciseFiles\\04_01_begin'
